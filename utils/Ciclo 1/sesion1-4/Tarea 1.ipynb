# %% [markdown]
# # Ejercicios resueltos

# %% [markdown]
# A continuacion se presentan los ejercicios propuestos codificados en Python.

# %% [markdown]
# ## Seccion 1

# %% [markdown]
# Crear un programa que calcule el resultado de las siguientes expresiones:

# %% [markdown]
# 1. $\sqrt(b^2 - 4ac)$
#
# 2. $\frac{x^2 + y^2}{z^2}$
#
# 3. $\frac{3x+2y}{2z}$
#
# 4. $\frac{a+b}{c-d}$
#
# 5. $4x^2-2x+7$
#
# 6. $\frac{x+y}{x} - \frac{3x}{5}$

# %%
option = 0
while option not in range(1,7):
    try:
        option = int(input("Digite una opcion de las listadas anteriormente para dar inicio: "))
        if option not in range(1,7):
            print("La opcion digitada no es válida. Intente nuevamente")
    except:
        option = 0
        print("No digito una opcion valida (número). Intente de nuevo")

print("Iniciando Ejercicio ", option)
# Out:
# Digite una opcion de las listadas anteriormente para dar inicio: 5
# Iniciando Ejercicio  5

# %%
if option in [1,4]:
    # Pedir a, b, c
    while True:
        try: 
            a = float(input("Digite el valor de la variable a:"))
            b = float(input("Digite el valor de la variable b:"))
            c = float(input("Digite el valor de la variable c:"))
            break
        except:
            print("Ingreso un valor no válido. Intente nuevamente")
    if option == 4:
        # Pedir d
        while True:
            try: 
                d = float(input("Digite el valor de la variable d:"))
                break
            except:
                print("Ingreso un valor no válido. Intente nuevamente")
else:
    # Pedir el valor de x
    while True:
        try: 
            x = float(input("Digite el valor de la variable x:"))
            break
        except:
            print("Ingreso un valor no válido. Intente nuevamente")
    if option in [2,3,6]:
        # Pedir el valor de y
        while True:
            try: 
                y = float(input("Digite el valor de la variable y:"))
                break
            except:
                print("Ingreso un valor no válido. Intente nuevamente")
    if option in [2,3]:
        # Pedir z
        while True:
            try: 
                z = float(input("Digite el valor de la variable z:"))
                break
            except:
                print("Ingreso un valor no válido. Intente nuevamente")
# Out:
# Digite el valor de la variable x:5

# %%
import math
# Hacemos las operaciones pero tengamos cuidado con las divisiones entre cero y las raices de numeros negativos.
res = 0.0
if option == 1:
    # Opcion 1, Cuidado con las raices negativas.
    try:
        res = math.sqrt((b**2)-(4*a*c))
    except:
        print("Se encontró la raíz de un numero negativo, la cual no esta definida en el espacio de los numeros reales. Por favor intente nuevamente con otro valores.")
elif option == 2:
    # Opcion 2, Cuidado con las divisiones por cero.
    try:
        res = (x**2 + y**2)/(z**2)
    except:
        print("Se encontró una division por cero, la cual no esta definida en el espacio de los numeros reales. Por favor intente nuevamente con otro valores.")
elif option == 3:
    # Opcion 3, Cuidado con las divisiones por cero.
    try:
        res = (3*x + 2*y)/(2*z)
    except:
        print("Se encontró una division por cero, la cual no esta definida en el espacio de los numeros reales. Por favor intente nuevamente con otro valores.")
elif option == 4:
    # Opcion 4, Cuidado con las divisiones por cero.
    try:
        res = (a+b)/(c-d)
    except:
        print("Se encontró una division por cero, la cual no esta definida en el espacio de los numeros reales. Por favor intente nuevamente con otro valores.")
elif option == 5:
    # Opcion 5, No hay problema.
    res = 4*(x**2) - 2*x + 7
else:
    # Opcion 6, Cuidado con las divisiones por cero.
    try:
        res = ((x+y)/(x)) - (3*x/5)
    except:
        print("Se encontró una division por cero, la cual no esta definida en el espacio de los numeros reales. Por favor intente nuevamente con otro valores.")

print("El resultado es: ", res)
# Out:
# El resultado es:  97.0

# %% [markdown]
# ## Seccion 2

# %% [markdown]
# Escribir un programa que convierta las longitudes del sistema inglés al sistema metrico decimal. Es decir, expresarlas en metros:

# %% [markdown]
# A. Convertir millas a kilometros. Tenga en cuenta que $1 mi = 1.609344 km$
#
# B. Convertir pies a centimetros. Tenga en cuenta que $1 ft = 30.48 cm$
#
# C. Convertir pulgadas a centimetros. Tenga en cuenta que $1 in = 2.54 cm$

# %%
option2 = 0
while option2 not in range(1,4):
    try:
        option2 = int(input("Digite una opcion de las listadas anteriormente para dar inicio: "))
        if option2 not in range(1,4):
            print("La opcion digitada no es válida. Intente nuevamente")
    except:
        option2 = 0
        print("No digito una opcion valida (número). Intente de nuevo")

print("Iniciando Ejercicio ", option2)
# Out:
# Digite una opcion de las listadas anteriormente para dar inicio: 1
# Iniciando Ejercicio  1

# %%
medidas = ['millas', 'pies', 'pulgadas']
while True:
    try: 
        valor = float(input("Digite la cantidad de "+ medidas[option2-1] + " a convertir: "))
        break
    except:
        print("Ingreso un valor no válido. Intente nuevamente")
# Out:
# Digite la cantidad de millas a convertir: 20

# %%
convertidos = ['kilometros', 'centimetros', 'centimetros']
multiplos = [1.609344, 30.48, 2.54]
print(str(valor)+" "+medidas[option2-1]+" equivalen a: "+ str(valor*multiplos[option2-1])+" "+ convertidos[option2-1])
# Out:
# 20.0 millas equivalen a: 32.18688 kilometros
